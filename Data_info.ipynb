# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('masterCSVfmfull.csv', parse_dates=True)
pd.to_datetime(data['year'], format='%Y')
# Out:
# 0       1985-01-01
# 1       1985-01-01
# 2       1985-01-01
# 3       1985-01-01
# 4       1985-01-01
# 5       1985-01-01
# 6       1986-01-01
# 7       1986-01-01
# 8       1986-01-01
# 9       1986-01-01
# 10      1986-01-01
# 11      1986-01-01
# 12      1987-01-01
# 13      1987-01-01
# 14      1987-01-01
# 15      1987-01-01
# 16      1987-01-01
# 17      1987-01-01
# 18      1988-01-01
# 19      1988-01-01
# 20      1988-01-01
# 21      1988-01-01
# 22      1988-01-01
# 23      1988-01-01
# 24      1989-01-01
# 25      1989-01-01
# 26      1989-01-01
# 27      1989-01-01
# 28      1989-01-01
# 29      1989-01-01
#            ...
# 38754   2012-01-01
# 38755   2012-01-01
# 38756   2012-01-01
# 38757   2012-01-01
# 38758   2012-01-01
# 38759   2012-01-01
# 38760   2013-01-01
# 38761   2013-01-01
# 38762   2013-01-01
# 38763   2013-01-01
# 38764   2013-01-01
# 38765   2013-01-01
# 38766   2014-01-01
# 38767   2014-01-01
# 38768   2014-01-01
# 38769   2014-01-01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38784 entries, 0 to 38783
# Data columns (total 11 columns):
# sex                   38784 non-null object
# country               38784 non-null object
# year                  38784 non-null int64
# age                   38784 non-null object
# generation            27820 non-null object
# suicides_no           27820 non-null float64
# population            27820 non-null float64
# suicides/100k pop     27820 non-null float64
# HDI for year          8364 non-null float64
# gdp_for_year ($)      27820 non-null float64
# gdp_per_capita ($)    27820 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 3.3+ MB

# %%
print(data.shape)
print(data.columns)
print(data.index)
# Out:
# (38784, 11)
# Index(['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#        'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')
# RangeIndex(start=0, stop=38784, step=1)

# %%
data.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  38784.000000  27820.000000  2.782000e+04       27820.000000
# mean    2000.500000    242.574407  1.844794e+06          12.816097
# std        9.233212    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1992.750000      3.000000  9.749850e+04           0.920000
# 50%     2000.500000     25.000000  4.301500e+05           5.990000
# 75%     2008.250000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_for_year ($)   gdp_per_capita ($)
# count   8364.000000       2.782000e+04        27820.000000
# mean     698.171765       4.455810e+11        16866.464414
# std      247.902248       1.453610e+12        18887.576472
# min        0.630000       4.691962e+07          251.000000
# 25%      673.000000       8.985353e+09         3447.000000
# ...

# %%
data
# Out:
#           sex     country  year          age       generation  suicides_no  \
# 0      female     Albania  1985  15-24 years              NaN          NaN
# 1      female     Albania  1985  25-34 years              NaN          NaN
# 2      female     Albania  1985  35-54 years              NaN          NaN
# 3      female     Albania  1985   5-14 years              NaN          NaN
# 4      female     Albania  1985  55-74 years              NaN          NaN
# 5      female     Albania  1985    75+ years              NaN          NaN
# 6      female     Albania  1986  15-24 years              NaN          NaN
# 7      female     Albania  1986  25-34 years              NaN          NaN
# 8      female     Albania  1986  35-54 years              NaN          NaN
# 9      female     Albania  1986   5-14 years              NaN          NaN
# 10     female     Albania  1986  55-74 years              NaN          NaN
# ...
