# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
data = pd.read_csv('masterCSVfmfull.csv')

# %%
agg_suno_w = data.groupby('country')[['suicides_no', 'suicides/100k pop']].agg(['sum'])
agg_suno_w = agg_suno_w.reset_index()

# %%
agg_suno_w
# Out:
#                           country suicides_no suicides/100k pop
#                                           sum               sum
# 0                         Albania      1970.0            924.76
# 1             Antigua and Barbuda        11.0            179.14
# 2                       Argentina     82219.0           3894.59
# 3                         Armenia      1905.0            976.21
# 4                           Aruba       101.0           1596.52
# 5                       Australia     70111.0           4677.41
# 6                         Austria     50073.0           9076.23
# 7                      Azerbaijan      1656.0            356.24
# 8                         Bahamas        93.0            344.28
# 9                         Bahrain       463.0            467.24
# 10                       Barbados       177.0            891.13
# 11                        Belarus     59892.0           7831.13
# 12                        Belgium     62761.0           7900.50
# ...

# %%
agg_suno_w.to_csv('Suma liczby i per100kpop dla kraju.csv')

# %%
data.columns
# Out:
# Index(['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#        'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')
