# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('masterCSVfmfull.csv')
data
data.columns
# Out:
# Index(['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#        'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')

# %%
data
# Out:
#           sex     country  year          age       generation  suicides_no  \
# 0      female     Albania  1985  15-24 years              NaN          NaN
# 1      female     Albania  1985  25-34 years              NaN          NaN
# 2      female     Albania  1985  35-54 years              NaN          NaN
# 3      female     Albania  1985   5-14 years              NaN          NaN
# 4      female     Albania  1985  55-74 years              NaN          NaN
# 5      female     Albania  1985    75+ years              NaN          NaN
# 6      female     Albania  1986  15-24 years              NaN          NaN
# 7      female     Albania  1986  25-34 years              NaN          NaN
# 8      female     Albania  1986  35-54 years              NaN          NaN
# 9      female     Albania  1986   5-14 years              NaN          NaN
# 10     female     Albania  1986  55-74 years              NaN          NaN
# 11     female     Albania  1986    75+ years              NaN          NaN
# 12     female     Albania  1987  15-24 years     Generation X         14.0
# 13     female     Albania  1987  25-34 years          Boomers          4.0
# 14     female     Albania  1987  35-54 years           Silent          6.0
# 15     female     Albania  1987   5-14 years     Generation X          0.0
# 16     female     Albania  1987  55-74 years  G.I. Generation          0.0
# 17     female     Albania  1987    75+ years  G.I. Generation          1.0
# 18     female     Albania  1988  15-24 years     Generation X          8.0
# 19     female     Albania  1988  25-34 years          Boomers          5.0
# 20     female     Albania  1988  35-54 years           Silent          4.0
# 21     female     Albania  1988   5-14 years     Generation X          0.0
# 22     female     Albania  1988  55-74 years  G.I. Generation          3.0
# 23     female     Albania  1988    75+ years  G.I. Generation          2.0
# 24     female     Albania  1989  15-24 years     Generation X          5.0
# 25     female     Albania  1989  25-34 years          Boomers          2.0
# 26     female     Albania  1989  35-54 years           Silent          7.0
# 27     female     Albania  1989   5-14 years     Generation X          0.0
# 28     female     Albania  1989  55-74 years  G.I. Generation          1.0
# 29     female     Albania  1989    75+ years  G.I. Generation          0.0
# ...       ...         ...   ...          ...              ...          ...
# 38754    male  Uzbekistan  2012  15-24 years       Millenials        311.0
# 38755    male  Uzbekistan  2012  25-34 years       Millenials        290.0
# 38756    male  Uzbekistan  2012  35-54 years     Generation X        404.0
# 38757    male  Uzbekistan  2012   5-14 years     Generation Z         67.0
# 38758    male  Uzbekistan  2012  55-74 years          Boomers        133.0
# 38759    male  Uzbekistan  2012    75+ years           Silent         15.0
# 38760    male  Uzbekistan  2013  15-24 years       Millenials        320.0
# 38761    male  Uzbekistan  2013  25-34 years       Millenials        328.0
# 38762    male  Uzbekistan  2013  35-54 years     Generation X        481.0
# 38763    male  Uzbekistan  2013   5-14 years     Generation Z         61.0
# 38764    male  Uzbekistan  2013  55-74 years          Boomers        119.0
# 38765    male  Uzbekistan  2013    75+ years           Silent         13.0
# 38766    male  Uzbekistan  2014  15-24 years       Millenials        347.0
# 38767    male  Uzbekistan  2014  25-34 years       Millenials        318.0
# 38768    male  Uzbekistan  2014  35-54 years     Generation X        519.0
# 38769    male  Uzbekistan  2014   5-14 years     Generation Z         60.0
# 38770    male  Uzbekistan  2014  55-74 years          Boomers        144.0
# 38771    male  Uzbekistan  2014    75+ years           Silent         17.0
# 38772    male  Uzbekistan  2015  15-24 years              NaN          NaN
# 38773    male  Uzbekistan  2015  25-34 years              NaN          NaN
# 38774    male  Uzbekistan  2015  35-54 years              NaN          NaN
# 38775    male  Uzbekistan  2015   5-14 years              NaN          NaN
# 38776    male  Uzbekistan  2015  55-74 years              NaN          NaN
# 38777    male  Uzbekistan  2015    75+ years              NaN          NaN
# 38778    male  Uzbekistan  2016  15-24 years              NaN          NaN
# 38779    male  Uzbekistan  2016  25-34 years              NaN          NaN
# 38780    male  Uzbekistan  2016  35-54 years              NaN          NaN
# 38781    male  Uzbekistan  2016   5-14 years              NaN          NaN
# 38782    male  Uzbekistan  2016  55-74 years              NaN          NaN
# 38783    male  Uzbekistan  2016    75+ years              NaN          NaN
#
#        population  suicides/100k pop  HDI for year  gdp_for_year ($)   \
# 0             NaN                NaN           NaN                NaN
# 1             NaN                NaN           NaN                NaN
# 2             NaN                NaN           NaN                NaN
# 3             NaN                NaN           NaN                NaN
# 4             NaN                NaN           NaN                NaN
# 5             NaN                NaN           NaN                NaN
# 6             NaN                NaN           NaN                NaN
# 7             NaN                NaN           NaN                NaN
# 8             NaN                NaN           NaN                NaN
# 9             NaN                NaN           NaN                NaN
# 10            NaN                NaN           NaN                NaN
# 11            NaN                NaN           NaN                NaN
# 12       289700.0               4.83           NaN       2.156625e+09
# 13       257200.0               1.56           NaN       2.156625e+09
# 14       278800.0               2.15           NaN       2.156625e+09
# 15       311000.0               0.00           NaN       2.156625e+09
# 16       144600.0               0.00           NaN       2.156625e+09
# 17        35600.0               2.81           NaN       2.156625e+09
# 18       295600.0               2.71           NaN       2.126000e+09
# 19       262400.0               1.91           NaN       2.126000e+09
# 20       284500.0               1.41           NaN       2.126000e+09
# 21       317200.0               0.00           NaN       2.126000e+09
# 22       147500.0               2.03           NaN       2.126000e+09
# 23        36400.0               5.49           NaN       2.126000e+09
# 24       299900.0               1.67           NaN       2.335125e+09
# 25       266300.0               0.75           NaN       2.335125e+09
# 26       288600.0               2.43           NaN       2.335125e+09
# 27       321900.0               0.00           NaN       2.335125e+09
# 28       149600.0               0.67           NaN       2.335125e+09
# 29        37000.0               0.00           NaN       2.335125e+09
# ...           ...                ...           ...                ...
# 38754   3199204.0               9.72         668.0       5.182157e+10
# 38755   2548472.0              11.38         668.0       5.182157e+10
# 38756   3273281.0              12.34         668.0       5.182157e+10
# 38757   2701361.0               2.48         668.0       5.182157e+10
# 38758   1141487.0              11.65         668.0       5.182157e+10
# 38759    213713.0               7.02         668.0       5.182157e+10
# 38760   3171202.0              10.09         672.0       5.769045e+10
# 38761   2644648.0              12.40         672.0       5.769045e+10
# 38762   3346411.0              14.37         672.0       5.769045e+10
# 38763   2720938.0               2.24         672.0       5.769045e+10
# 38764   1202790.0               9.89         672.0       5.769045e+10
# 38765    221002.0               5.88         672.0       5.769045e+10
# 38766   3126905.0              11.10         675.0       6.306708e+10
# 38767   2739150.0              11.61         675.0       6.306708e+10
# 38768   3421300.0              15.17         675.0       6.306708e+10
# 38769   2762158.0               2.17         675.0       6.306708e+10
# 38770   1271111.0              11.33         675.0       6.306708e+10
# 38771    224995.0               7.56         675.0       6.306708e+10
# 38772         NaN                NaN           NaN                NaN
# 38773         NaN                NaN           NaN                NaN
# 38774         NaN                NaN           NaN                NaN
# 38775         NaN                NaN           NaN                NaN
# 38776         NaN                NaN           NaN                NaN
# 38777         NaN                NaN           NaN                NaN
# 38778         NaN                NaN           NaN                NaN
# 38779         NaN                NaN           NaN                NaN
# 38780         NaN                NaN           NaN                NaN
# 38781         NaN                NaN           NaN                NaN
# 38782         NaN                NaN           NaN                NaN
# 38783         NaN                NaN           NaN                NaN
#
#        gdp_per_capita ($)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                  796.0
# 13                  796.0
# 14                  796.0
# 15                  796.0
# 16                  796.0
# 17                  796.0
# 18                  769.0
# 19                  769.0
# 20                  769.0
# 21                  769.0
# 22                  769.0
# 23                  769.0
# 24                  833.0
# 25                  833.0
# 26                  833.0
# 27                  833.0
# 28                  833.0
# 29                  833.0
# ...                   ...
# 38754              1964.0
# 38755              1964.0
# 38756              1964.0
# 38757              1964.0
# 38758              1964.0
# 38759              1964.0
# 38760              2150.0
# 38761              2150.0
# 38762              2150.0
# 38763              2150.0
# 38764              2150.0
# 38765              2150.0
# 38766              2309.0
# 38767              2309.0
# 38768              2309.0
# 38769              2309.0
# 38770              2309.0
# 38771              2309.0
# 38772                 NaN
# 38773                 NaN
# 38774                 NaN
# 38775                 NaN
# 38776                 NaN
# 38777                 NaN
# 38778                 NaN
# 38779                 NaN
# 38780                 NaN
# 38781                 NaN
# 38782                 NaN
# 38783                 NaN
#
# [38784 rows x 11 columns]

# %%
X = ['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
       'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
       'Barbados', 'Belarus', 'Belgium', 'Belize',
       'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
       'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
       'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
       'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
       'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
       'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
       'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
       'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
       'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
       'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
       'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
       'Republic of Korea', 'Romania', 'Russian Federation',
       'Saint Kitts and Nevis', 'Saint Lucia',
       'Saint Vincent and Grenadines', 'San Marino', 'Serbia',
       'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa',
       'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland',
       'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
       'Ukraine', 'United Arab Emirates', 'United Kingdom',
       'United States', 'Uruguay', 'Uzbekistan']

# %%
len(X)
# Out:
# 101

# %%
data['year'] = data['year'].astype('category')
data['year']
# Out:
# 0        1985
# 1        1985
# 2        1985
# 3        1985
# 4        1985
# 5        1985
# 6        1986
# 7        1986
# 8        1986
# 9        1986
# 10       1986
# 11       1986
# 12       1987
# 13       1987
# 14       1987
# 15       1987
# 16       1987
# 17       1987
# 18       1988
# 19       1988
# 20       1988
# 21       1988
# 22       1988
# 23       1988
# 24       1989
# 25       1989
# 26       1989
# 27       1989
# 28       1989
# 29       1989
#          ...
# 38754    2012
# 38755    2012
# 38756    2012
# 38757    2012
# 38758    2012
# 38759    2012
# 38760    2013
# 38761    2013
# 38762    2013
# 38763    2013
# 38764    2013
# 38765    2013
# 38766    2014
# 38767    2014
# 38768    2014
# 38769    2014
# 38770    2014
# 38771    2014
# 38772    2015
# 38773    2015
# 38774    2015
# 38775    2015
# 38776    2015
# 38777    2015
# 38778    2016
# 38779    2016
# 38780    2016
# 38781    2016
# 38782    2016
# 38783    2016
# Name: year, Length: 38784, dtype: category
# Categories (32, int64): [1985, 1986, 1987, 1988, ..., 2013, 2014, 2015, 2016]

# %%
Y = data['year'].unique()
Y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-39103946d7d5> in <module>()
#       1 Y = data['year'].unique()
# ----> 2 Y.index
#
# AttributeError: 'Categorical' object has no attribute 'index'

# %%
Y.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-790342bfb618> in <module>()
# ----> 1 Y.sum()
#
# AttributeError: 'Categorical' object has no attribute 'sum'

# %%
data['year'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-99a430899ec7> in <module>()
# ----> 1 data['year'].unique().sum()
#
# AttributeError: 'Categorical' object has no attribute 'sum'

# %%
data.drop_duplicates()
# Out:
#        sex     country  year          age       generation  suicides_no  \
# 0      1.0     Albania  1985  15-24 years              NaN          NaN
# 1      1.0     Albania  1985  25-34 years              NaN          NaN
# 2      1.0     Albania  1985  35-54 years              NaN          NaN
# 3      1.0     Albania  1985   5-14 years              NaN          NaN
# 4      1.0     Albania  1985  55-74 years              NaN          NaN
# 5      1.0     Albania  1985    75+ years              NaN          NaN
# 6      1.0     Albania  1986  15-24 years              NaN          NaN
# 7      1.0     Albania  1986  25-34 years              NaN          NaN
# 8      1.0     Albania  1986  35-54 years              NaN          NaN
# 9      1.0     Albania  1986   5-14 years              NaN          NaN
# 10     1.0     Albania  1986  55-74 years              NaN          NaN
# 11     1.0     Albania  1986    75+ years              NaN          NaN
# 12     1.0     Albania  1987  15-24 years     Generation X         14.0
# 13     1.0     Albania  1987  25-34 years          Boomers          4.0
# 14     1.0     Albania  1987  35-54 years           Silent          6.0
# 15     1.0     Albania  1987   5-14 years     Generation X          0.0
# 16     1.0     Albania  1987  55-74 years  G.I. Generation          0.0
# 17     1.0     Albania  1987    75+ years  G.I. Generation          1.0
# 18     1.0     Albania  1988  15-24 years     Generation X          8.0
# 19     1.0     Albania  1988  25-34 years          Boomers          5.0
# 20     1.0     Albania  1988  35-54 years           Silent          4.0
# 21     1.0     Albania  1988   5-14 years     Generation X          0.0
# 22     1.0     Albania  1988  55-74 years  G.I. Generation          3.0
# 23     1.0     Albania  1988    75+ years  G.I. Generation          2.0
# 24     1.0     Albania  1989  15-24 years     Generation X          5.0
# 25     1.0     Albania  1989  25-34 years          Boomers          2.0
# 26     1.0     Albania  1989  35-54 years           Silent          7.0
# 27     1.0     Albania  1989   5-14 years     Generation X          0.0
# 28     1.0     Albania  1989  55-74 years  G.I. Generation          1.0
# 29     1.0     Albania  1989    75+ years  G.I. Generation          0.0
# ...    ...         ...   ...          ...              ...          ...
# 38742  1.0  Uzbekistan  2010  15-24 years       Millenials        246.0
# 38743  1.0  Uzbekistan  2010  25-34 years     Generation X        235.0
# 38744  1.0  Uzbekistan  2010  35-54 years     Generation X        371.0
# 38745  1.0  Uzbekistan  2010   5-14 years     Generation Z         48.0
# 38746  1.0  Uzbekistan  2010  55-74 years           Silent        102.0
# 38747  1.0  Uzbekistan  2010    75+ years           Silent          9.0
# 38748  1.0  Uzbekistan  2011  15-24 years       Millenials        264.0
# 38749  1.0  Uzbekistan  2011  25-34 years       Millenials        271.0
# 38750  1.0  Uzbekistan  2011  35-54 years     Generation X        457.0
# 38751  1.0  Uzbekistan  2011   5-14 years     Generation Z         45.0
# 38752  1.0  Uzbekistan  2011  55-74 years          Boomers         76.0
# 38753  1.0  Uzbekistan  2011    75+ years           Silent         10.0
# 38754  1.0  Uzbekistan  2012  15-24 years       Millenials        311.0
# 38755  1.0  Uzbekistan  2012  25-34 years       Millenials        290.0
# 38756  1.0  Uzbekistan  2012  35-54 years     Generation X        404.0
# 38757  1.0  Uzbekistan  2012   5-14 years     Generation Z         67.0
# 38758  1.0  Uzbekistan  2012  55-74 years          Boomers        133.0
# 38759  1.0  Uzbekistan  2012    75+ years           Silent         15.0
# 38760  1.0  Uzbekistan  2013  15-24 years       Millenials        320.0
# 38761  1.0  Uzbekistan  2013  25-34 years       Millenials        328.0
# 38762  1.0  Uzbekistan  2013  35-54 years     Generation X        481.0
# 38763  1.0  Uzbekistan  2013   5-14 years     Generation Z         61.0
# 38764  1.0  Uzbekistan  2013  55-74 years          Boomers        119.0
# 38765  1.0  Uzbekistan  2013    75+ years           Silent         13.0
# 38766  1.0  Uzbekistan  2014  15-24 years       Millenials        347.0
# 38767  1.0  Uzbekistan  2014  25-34 years       Millenials        318.0
# 38768  1.0  Uzbekistan  2014  35-54 years     Generation X        519.0
# 38769  1.0  Uzbekistan  2014   5-14 years     Generation Z         60.0
# 38770  1.0  Uzbekistan  2014  55-74 years          Boomers        144.0
# 38771  1.0  Uzbekistan  2014    75+ years           Silent         17.0
#
#        population  suicides/100k pop  HDI for year  gdp_for_year ($)   \
# 0             NaN                NaN           NaN                NaN
# 1             NaN                NaN           NaN                NaN
# 2             NaN                NaN           NaN                NaN
# 3             NaN                NaN           NaN                NaN
# 4             NaN                NaN           NaN                NaN
# 5             NaN                NaN           NaN                NaN
# 6             NaN                NaN           NaN                NaN
# 7             NaN                NaN           NaN                NaN
# 8             NaN                NaN           NaN                NaN
# 9             NaN                NaN           NaN                NaN
# 10            NaN                NaN           NaN                NaN
# 11            NaN                NaN           NaN                NaN
# 12       289700.0               4.83           NaN       2.156625e+09
# 13       257200.0               1.56           NaN       2.156625e+09
# 14       278800.0               2.15           NaN       2.156625e+09
# 15       311000.0               0.00           NaN       2.156625e+09
# 16       144600.0               0.00           NaN       2.156625e+09
# 17        35600.0               2.81           NaN       2.156625e+09
# 18       295600.0               2.71           NaN       2.126000e+09
# 19       262400.0               1.91           NaN       2.126000e+09
# 20       284500.0               1.41           NaN       2.126000e+09
# 21       317200.0               0.00           NaN       2.126000e+09
# 22       147500.0               2.03           NaN       2.126000e+09
# 23        36400.0               5.49           NaN       2.126000e+09
# 24       299900.0               1.67           NaN       2.335125e+09
# 25       266300.0               0.75           NaN       2.335125e+09
# 26       288600.0               2.43           NaN       2.335125e+09
# 27       321900.0               0.00           NaN       2.335125e+09
# 28       149600.0               0.67           NaN       2.335125e+09
# 29        37000.0               0.00           NaN       2.335125e+09
# ...           ...                ...           ...                ...
# 38742   3208299.0               7.67         655.0       3.933277e+10
# 38743   2375259.0               9.89         655.0       3.933277e+10
# 38744   3142694.0              11.81         655.0       3.933277e+10
# 38745   2751752.0               1.74         655.0       3.933277e+10
# 38746   1036963.0               9.84         655.0       3.933277e+10
# 38747    196160.0               4.59         655.0       3.933277e+10
# 38748   3211080.0               8.22         661.0       4.591519e+10
# 38749   2457050.0              11.03         661.0       4.591519e+10
# 38750   3204569.0              14.26         661.0       4.591519e+10
# 38751   2710780.0               1.66         661.0       4.591519e+10
# 38752   1086405.0               7.00         661.0       4.591519e+10
# 38753    204956.0               4.88         661.0       4.591519e+10
# 38754   3199204.0               9.72         668.0       5.182157e+10
# 38755   2548472.0              11.38         668.0       5.182157e+10
# 38756   3273281.0              12.34         668.0       5.182157e+10
# 38757   2701361.0               2.48         668.0       5.182157e+10
# 38758   1141487.0              11.65         668.0       5.182157e+10
# 38759    213713.0               7.02         668.0       5.182157e+10
# 38760   3171202.0              10.09         672.0       5.769045e+10
# 38761   2644648.0              12.40         672.0       5.769045e+10
# 38762   3346411.0              14.37         672.0       5.769045e+10
# 38763   2720938.0               2.24         672.0       5.769045e+10
# 38764   1202790.0               9.89         672.0       5.769045e+10
# 38765    221002.0               5.88         672.0       5.769045e+10
# 38766   3126905.0              11.10         675.0       6.306708e+10
# 38767   2739150.0              11.61         675.0       6.306708e+10
# 38768   3421300.0              15.17         675.0       6.306708e+10
# 38769   2762158.0               2.17         675.0       6.306708e+10
# 38770   1271111.0              11.33         675.0       6.306708e+10
# 38771    224995.0               7.56         675.0       6.306708e+10
#
#        gdp_per_capita ($)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                  796.0
# 13                  796.0
# 14                  796.0
# 15                  796.0
# 16                  796.0
# 17                  796.0
# 18                  769.0
# 19                  769.0
# 20                  769.0
# 21                  769.0
# 22                  769.0
# 23                  769.0
# 24                  833.0
# 25                  833.0
# 26                  833.0
# 27                  833.0
# 28                  833.0
# 29                  833.0
# ...                   ...
# 38742              1533.0
# 38743              1533.0
# 38744              1533.0
# 38745              1533.0
# 38746              1533.0
# 38747              1533.0
# 38748              1767.0
# 38749              1767.0
# 38750              1767.0
# 38751              1767.0
# 38752              1767.0
# 38753              1767.0
# 38754              1964.0
# 38755              1964.0
# 38756              1964.0
# 38757              1964.0
# 38758              1964.0
# 38759              1964.0
# 38760              2150.0
# 38761              2150.0
# 38762              2150.0
# 38763              2150.0
# 38764              2150.0
# 38765              2150.0
# 38766              2309.0
# 38767              2309.0
# 38768              2309.0
# 38769              2309.0
# 38770              2309.0
# 38771              2309.0
#
# [33284 rows x 11 columns]

# %%
S = ['female', 'male']

# %%
len (data['sex'].
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-e7d6c18117ad> in <module>()
# ----> 1 len (data['sex'].count())
#
# TypeError: object of type 'numpy.int32' has no len()

# %%
eu = pd.read_csv('countries europe1.csv')
eu
# Out:
#                 EUC
# 0           Austria
# 1           Belgium
# 2          Bulgaria
# 3           Croatia
# 4            Cyprus
# 5    Czech Republic
# 6           Denmark
# 7           Estonia
# 8           Finland
# 9            France
# 10          Germany
# 11           Greece
# 12          Hungary
# 13          Ireland
# 14            Italy
# 15           Latvia
# 16        Lithuania
# 17       Luxembourg
# 18            Malta
# 19      Netherlands
# 20           Poland
# 21         Portugal
# 22          Romania
# 23  Slovak Republic
# 24         Slovenia
# 25            Spain
# 26           Sweden
# 27   United Kingdom

# %%
data['suicides_no'].sum()
# Out:
# 6748420.0

# %%
data['country'].unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Korea', 'Romania', 'Russian Federation',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and Grenadines', 'San Marino', 'Serbia',
#        'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
#df = pd.DataFrame(data, columns = ['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#      'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#      'gdp_per_capita ($)'])

#df = pd.DataFrame(data)
#df
pd.unique(['country'])
# Out:
# array(['country'], dtype=object)

# %%
data.set_index('country', inplace=True)
data
# Out:
#                sex  year          age       generation  suicides_no  \
# country
# Albania     female  1985  15-24 years              NaN          NaN
# Albania     female  1985  25-34 years              NaN          NaN
# Albania     female  1985  35-54 years              NaN          NaN
# Albania     female  1985   5-14 years              NaN          NaN
# Albania     female  1985  55-74 years              NaN          NaN
# Albania     female  1985    75+ years              NaN          NaN
# Albania     female  1986  15-24 years              NaN          NaN
# Albania     female  1986  25-34 years              NaN          NaN
# Albania     female  1986  35-54 years              NaN          NaN
# Albania     female  1986   5-14 years              NaN          NaN
# Albania     female  1986  55-74 years              NaN          NaN
# Albania     female  1986    75+ years              NaN          NaN
# Albania     female  1987  15-24 years     Generation X         14.0
# Albania     female  1987  25-34 years          Boomers          4.0
# Albania     female  1987  35-54 years           Silent          6.0
# Albania     female  1987   5-14 years     Generation X          0.0
# Albania     female  1987  55-74 years  G.I. Generation          0.0
# Albania     female  1987    75+ years  G.I. Generation          1.0
# Albania     female  1988  15-24 years     Generation X          8.0
# Albania     female  1988  25-34 years          Boomers          5.0
# Albania     female  1988  35-54 years           Silent          4.0
# Albania     female  1988   5-14 years     Generation X          0.0
# Albania     female  1988  55-74 years  G.I. Generation          3.0
# Albania     female  1988    75+ years  G.I. Generation          2.0
# Albania     female  1989  15-24 years     Generation X          5.0
# Albania     female  1989  25-34 years          Boomers          2.0
# Albania     female  1989  35-54 years           Silent          7.0
# Albania     female  1989   5-14 years     Generation X          0.0
# Albania     female  1989  55-74 years  G.I. Generation          1.0
# Albania     female  1989    75+ years  G.I. Generation          0.0
# ...            ...   ...          ...              ...          ...
# Uzbekistan    male  2012  15-24 years       Millenials        311.0
# Uzbekistan    male  2012  25-34 years       Millenials        290.0
# Uzbekistan    male  2012  35-54 years     Generation X        404.0
# Uzbekistan    male  2012   5-14 years     Generation Z         67.0
# Uzbekistan    male  2012  55-74 years          Boomers        133.0
# Uzbekistan    male  2012    75+ years           Silent         15.0
# Uzbekistan    male  2013  15-24 years       Millenials        320.0
# Uzbekistan    male  2013  25-34 years       Millenials        328.0
# Uzbekistan    male  2013  35-54 years     Generation X        481.0
# Uzbekistan    male  2013   5-14 years     Generation Z         61.0
# Uzbekistan    male  2013  55-74 years          Boomers        119.0
# Uzbekistan    male  2013    75+ years           Silent         13.0
# Uzbekistan    male  2014  15-24 years       Millenials        347.0
# Uzbekistan    male  2014  25-34 years       Millenials        318.0
# Uzbekistan    male  2014  35-54 years     Generation X        519.0
# Uzbekistan    male  2014   5-14 years     Generation Z         60.0
# Uzbekistan    male  2014  55-74 years          Boomers        144.0
# Uzbekistan    male  2014    75+ years           Silent         17.0
# Uzbekistan    male  2015  15-24 years              NaN          NaN
# Uzbekistan    male  2015  25-34 years              NaN          NaN
# Uzbekistan    male  2015  35-54 years              NaN          NaN
# Uzbekistan    male  2015   5-14 years              NaN          NaN
# Uzbekistan    male  2015  55-74 years              NaN          NaN
# Uzbekistan    male  2015    75+ years              NaN          NaN
# Uzbekistan    male  2016  15-24 years              NaN          NaN
# Uzbekistan    male  2016  25-34 years              NaN          NaN
# Uzbekistan    male  2016  35-54 years              NaN          NaN
# Uzbekistan    male  2016   5-14 years              NaN          NaN
# Uzbekistan    male  2016  55-74 years              NaN          NaN
# Uzbekistan    male  2016    75+ years              NaN          NaN
#
#             population  suicides/100k pop  HDI for year  gdp_for_year ($)   \
# country
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania            NaN                NaN           NaN                NaN
# Albania       289700.0               4.83           NaN       2.156625e+09
# Albania       257200.0               1.56           NaN       2.156625e+09
# Albania       278800.0               2.15           NaN       2.156625e+09
# Albania       311000.0               0.00           NaN       2.156625e+09
# Albania       144600.0               0.00           NaN       2.156625e+09
# Albania        35600.0               2.81           NaN       2.156625e+09
# Albania       295600.0               2.71           NaN       2.126000e+09
# Albania       262400.0               1.91           NaN       2.126000e+09
# Albania       284500.0               1.41           NaN       2.126000e+09
# Albania       317200.0               0.00           NaN       2.126000e+09
# Albania       147500.0               2.03           NaN       2.126000e+09
# Albania        36400.0               5.49           NaN       2.126000e+09
# Albania       299900.0               1.67           NaN       2.335125e+09
# Albania       266300.0               0.75           NaN       2.335125e+09
# Albania       288600.0               2.43           NaN       2.335125e+09
# Albania       321900.0               0.00           NaN       2.335125e+09
# Albania       149600.0               0.67           NaN       2.335125e+09
# Albania        37000.0               0.00           NaN       2.335125e+09
# ...                ...                ...           ...                ...
# Uzbekistan   3199204.0               9.72         668.0       5.182157e+10
# Uzbekistan   2548472.0              11.38         668.0       5.182157e+10
# Uzbekistan   3273281.0              12.34         668.0       5.182157e+10
# Uzbekistan   2701361.0               2.48         668.0       5.182157e+10
# Uzbekistan   1141487.0              11.65         668.0       5.182157e+10
# Uzbekistan    213713.0               7.02         668.0       5.182157e+10
# Uzbekistan   3171202.0              10.09         672.0       5.769045e+10
# Uzbekistan   2644648.0              12.40         672.0       5.769045e+10
# Uzbekistan   3346411.0              14.37         672.0       5.769045e+10
# Uzbekistan   2720938.0               2.24         672.0       5.769045e+10
# Uzbekistan   1202790.0               9.89         672.0       5.769045e+10
# Uzbekistan    221002.0               5.88         672.0       5.769045e+10
# Uzbekistan   3126905.0              11.10         675.0       6.306708e+10
# Uzbekistan   2739150.0              11.61         675.0       6.306708e+10
# Uzbekistan   3421300.0              15.17         675.0       6.306708e+10
# Uzbekistan   2762158.0               2.17         675.0       6.306708e+10
# Uzbekistan   1271111.0              11.33         675.0       6.306708e+10
# Uzbekistan    224995.0               7.56         675.0       6.306708e+10
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
# Uzbekistan         NaN                NaN           NaN                NaN
#
#             gdp_per_capita ($)
# country
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                    NaN
# Albania                  796.0
# Albania                  796.0
# Albania                  796.0
# Albania                  796.0
# Albania                  796.0
# Albania                  796.0
# Albania                  769.0
# Albania                  769.0
# Albania                  769.0
# Albania                  769.0
# Albania                  769.0
# Albania                  769.0
# Albania                  833.0
# Albania                  833.0
# Albania                  833.0
# Albania                  833.0
# Albania                  833.0
# Albania                  833.0
# ...                        ...
# Uzbekistan              1964.0
# Uzbekistan              1964.0
# Uzbekistan              1964.0
# Uzbekistan              1964.0
# Uzbekistan              1964.0
# Uzbekistan              1964.0
# Uzbekistan              2150.0
# Uzbekistan              2150.0
# Uzbekistan              2150.0
# Uzbekistan              2150.0
# Uzbekistan              2150.0
# Uzbekistan              2150.0
# Uzbekistan              2309.0
# Uzbekistan              2309.0
# Uzbekistan              2309.0
# Uzbekistan              2309.0
# Uzbekistan              2309.0
# Uzbekistan              2309.0
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
# Uzbekistan                 NaN
#
# [38784 rows x 10 columns]

# %%
data.count()
data.
# Out:
#   File "<ipython-input-5-88a03969dbdc>", line 2
#     data.
#          ^
# SyntaxError: invalid syntax

# %%
data['suicides_no'].sum()
# Out:
# 6748420.0

# %%
data.index
# Out:
# Index(['Albania', 'Albania', 'Albania', 'Albania', 'Albania', 'Albania',
#        'Albania', 'Albania', 'Albania', 'Albania',
#        ...
#        'Uzbekistan', 'Uzbekistan', 'Uzbekistan', 'Uzbekistan', 'Uzbekistan',
#        'Uzbekistan', 'Uzbekistan', 'Uzbekistan', 'Uzbekistan', 'Uzbekistan'],
#       dtype='object', name='country', length=38784)

# %%
data.columns
# Out:
# Index(['sex', 'year', 'age', 'generation', 'suicides_no', 'population',
#        'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')

# %%
c_anb = data.loc['Uzbekistan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Uzbekistan] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-86affa294fda> in <module>()
# ----> 1 c_anb = data.loc['Uzbekistan']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [Uzbekistan] is not in the [index]'

# %%
c_anb['suicides_no'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-939e9eec6f34> in <module>()
# ----> 1 c_anb['suicides_no'].sum()
#
# NameError: name 'c_anb' is not defined

# %%
x = data['year']
y = data['suicides_no']
plt.bar(x,y)
plt.show()

# %%
data['country'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-0a911a06a596> in <module>()
# ----> 1 data['country'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'

# %%
c_ala = data.loc[['Albania']]
c_ala
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-cb12ea76f6a5> in <module>()
# ----> 1 c_ala = data.loc[['Albania']]
#       2 c_ala
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: "None of [['Albania']] are in the [index]"

# %%
c_ala['suicides_no'].sum()
# Out:
# 1970.0

# %%
c_ala['suicides_no'].value_counts()
# Out:
# 0.0     58
# 1.0     25
# 2.0     23
# 9.0     16
# 6.0     15
# 4.0     14
# 7.0     12
# 3.0     10
# 14.0     9
# 5.0      8
# 10.0     8
# 13.0     7
# 12.0     6
# 16.0     5
# 11.0     5
# 8.0      4
# 21.0     4
# 19.0     4
# 15.0     4
# 17.0     4
# 20.0     4
# 18.0     2
# 29.0     2
# 39.0     1
# 31.0     1
# 28.0     1
# 35.0     1
# 23.0     1
# 34.0     1
# 22.0     1
# 26.0     1
# 24.0     1
# 27.0     1
# 30.0     1
# 36.0     1
# 33.0     1
# 32.0     1
# 37.0     1
# Name: suicides_no, dtype: int64

# %%
c_ala['suicides_no'].value_counts().reset_index().sort_values(by='index').columns
# Out:
# Index(['index', 'suicides_no'], dtype='object')

# %%
snum = c_ala['suicides_no'].value_counts().reset_index().sort_values(by='index')
snum
# Out:
#     index  suicides_no
# 0     0.0           58
# 1     1.0           25
# 2     2.0           23
# 7     3.0           10
# 5     4.0           14
# 9     5.0            8
# 4     6.0           15
# 6     7.0           12
# 15    8.0            4
# 3     9.0           16
# 10   10.0            8
# 14   11.0            5
# 12   12.0            6
# 11   13.0            7
# 8    14.0            9
# 18   15.0            4
# 13   16.0            5
# 19   17.0            4
# 21   18.0            2
# 17   19.0            4
# 20   20.0            4
# 16   21.0            4
# 29   22.0            1
# 27   23.0            1
# 31   24.0            1
# 30   26.0            1
# 32   27.0            1
# 25   28.0            1
# 22   29.0            2
# 33   30.0            1
# 24   31.0            1
# 36   32.0            1
# 35   33.0            1
# 28   34.0            1
# 26   35.0            1
# 34   36.0            1
# 37   37.0            1
# 23   39.0            1

# %%
x = c_ala['country']
y = snum['suicides_no']
plt.bar(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-60fc28372ebc> in <module>()
# ----> 1 x = c_ala['country']
#       2 y = snum['suicides_no']
#       3 plt.bar(x,y)
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'

# %%
data[['country','year']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-108035fca9f3> in <module>()
# ----> 1 data[['country','year']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['country'] not in index"
