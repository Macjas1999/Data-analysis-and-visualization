# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('master_europa_olny.csv')

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data.columns
# Out:
# Index(['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#        'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')

# %%
data
# Out:
#           sex         country  year          age       generation  \
# 0      female         Albania  1985  15-24 years              NaN
# 1      female         Albania  1985  25-34 years              NaN
# 2      female         Albania  1985  35-54 years              NaN
# 3      female         Albania  1985   5-14 years              NaN
# 4      female         Albania  1985  55-74 years              NaN
# 5      female         Albania  1985    75+ years              NaN
# 6      female         Albania  1986  15-24 years              NaN
# 7      female         Albania  1986  25-34 years              NaN
# 8      female         Albania  1986  35-54 years              NaN
# 9      female         Albania  1986   5-14 years              NaN
# 10     female         Albania  1986  55-74 years              NaN
# 11     female         Albania  1986    75+ years              NaN
# 12     female         Albania  1987  15-24 years     Generation X
# 13     female         Albania  1987  25-34 years          Boomers
# 14     female         Albania  1987  35-54 years           Silent
# 15     female         Albania  1987   5-14 years     Generation X
# 16     female         Albania  1987  55-74 years  G.I. Generation
# 17     female         Albania  1987    75+ years  G.I. Generation
# 18     female         Albania  1988  15-24 years     Generation X
# 19     female         Albania  1988  25-34 years          Boomers
# 20     female         Albania  1988  35-54 years           Silent
# 21     female         Albania  1988   5-14 years     Generation X
# 22     female         Albania  1988  55-74 years  G.I. Generation
# 23     female         Albania  1988    75+ years  G.I. Generation
# 24     female         Albania  1989  15-24 years     Generation X
# 25     female         Albania  1989  25-34 years          Boomers
# 26     female         Albania  1989  35-54 years           Silent
# 27     female         Albania  1989   5-14 years     Generation X
# 28     female         Albania  1989  55-74 years  G.I. Generation
# 29     female         Albania  1989    75+ years  G.I. Generation
# ...       ...             ...   ...          ...              ...
# 14946    male  United Kingdom  2012  15-24 years       Millenials
# 14947    male  United Kingdom  2012  25-34 years       Millenials
# 14948    male  United Kingdom  2012  35-54 years     Generation X
# 14949    male  United Kingdom  2012   5-14 years     Generation Z
# 14950    male  United Kingdom  2012  55-74 years          Boomers
# 14951    male  United Kingdom  2012    75+ years           Silent
# 14952    male  United Kingdom  2013  15-24 years       Millenials
# 14953    male  United Kingdom  2013  25-34 years       Millenials
# 14954    male  United Kingdom  2013  35-54 years     Generation X
# 14955    male  United Kingdom  2013   5-14 years     Generation Z
# 14956    male  United Kingdom  2013  55-74 years          Boomers
# 14957    male  United Kingdom  2013    75+ years           Silent
# 14958    male  United Kingdom  2014  15-24 years       Millenials
# 14959    male  United Kingdom  2014  25-34 years       Millenials
# 14960    male  United Kingdom  2014  35-54 years     Generation X
# 14961    male  United Kingdom  2014   5-14 years     Generation Z
# 14962    male  United Kingdom  2014  55-74 years          Boomers
# 14963    male  United Kingdom  2014    75+ years           Silent
# 14964    male  United Kingdom  2015  15-24 years       Millenials
# 14965    male  United Kingdom  2015  25-34 years       Millenials
# 14966    male  United Kingdom  2015  35-54 years     Generation X
# 14967    male  United Kingdom  2015   5-14 years     Generation Z
# 14968    male  United Kingdom  2015  55-74 years          Boomers
# 14969    male  United Kingdom  2015    75+ years           Silent
# 14970    male  United Kingdom  2016  15-24 years              NaN
# 14971    male  United Kingdom  2016  25-34 years              NaN
# 14972    male  United Kingdom  2016  35-54 years              NaN
# 14973    male  United Kingdom  2016   5-14 years              NaN
# 14974    male  United Kingdom  2016  55-74 years              NaN
# 14975    male  United Kingdom  2016    75+ years              NaN
#
#        suicides_no  population  suicides/100k pop  HDI for year  \
# 0              NaN         NaN                NaN           NaN
# 1              NaN         NaN                NaN           NaN
# 2              NaN         NaN                NaN           NaN
# 3              NaN         NaN                NaN           NaN
# 4              NaN         NaN                NaN           NaN
# 5              NaN         NaN                NaN           NaN
# 6              NaN         NaN                NaN           NaN
# 7              NaN         NaN                NaN           NaN
# 8              NaN         NaN                NaN           NaN
# 9              NaN         NaN                NaN           NaN
# 10             NaN         NaN                NaN           NaN
# 11             NaN         NaN                NaN           NaN
# 12            14.0    289700.0               4.83           NaN
# 13             4.0    257200.0               1.56           NaN
# 14             6.0    278800.0               2.15           NaN
# 15             0.0    311000.0               0.00           NaN
# 16             0.0    144600.0               0.00           NaN
# 17             1.0     35600.0               2.81           NaN
# 18             8.0    295600.0               2.71           NaN
# 19             5.0    262400.0               1.91           NaN
# 20             4.0    284500.0               1.41           NaN
# 21             0.0    317200.0               0.00           NaN
# 22             3.0    147500.0               2.03           NaN
# 23             2.0     36400.0               5.49           NaN
# 24             5.0    299900.0               1.67           NaN
# 25             2.0    266300.0               0.75           NaN
# 26             7.0    288600.0               2.43           NaN
# 27             0.0    321900.0               0.00           NaN
# 28             1.0    149600.0               0.67           NaN
# 29             0.0     37000.0               0.00           NaN
# ...            ...         ...                ...           ...
# 14946        364.0   4204765.0               8.66         901.0
# 14947        597.0   4261254.0              14.01         901.0
# 14948       1587.0   8673006.0              18.30         901.0
# 14949         10.0   3695552.0               0.27         901.0
# 14950        739.0   6392214.0              11.56         901.0
# 14951        215.0   2043034.0              10.52         901.0
# 14952        331.0   4180873.0               7.92         902.0
# 14953        586.0   4320298.0              13.56         902.0
# 14954       1743.0   8656572.0              20.13         902.0
# 14955          5.0   3734237.0               0.13         902.0
# 14956        908.0   6488882.0              13.99         902.0
# 14957        258.0   2096518.0              12.31         902.0
# 14958        332.0   4171187.0               7.96         907.0
# 14959        602.0   4360457.0              13.81         907.0
# 14960       1692.0   8665195.0              19.53         907.0
# 14961          7.0   3778321.0               0.19         907.0
# 14962        827.0   6597480.0              12.54         907.0
# 14963        257.0   2158742.0              11.91         907.0
# 14964        374.0   4151992.0               9.01           NaN
# 14965        596.0   4408293.0              13.52           NaN
# 14966       1579.0   8692440.0              18.17           NaN
# 14967          4.0   3840476.0               0.10           NaN
# 14968        906.0   6716557.0              13.49           NaN
# 14969        273.0   2200958.0              12.40           NaN
# 14970          NaN         NaN                NaN           NaN
# 14971          NaN         NaN                NaN           NaN
# 14972          NaN         NaN                NaN           NaN
# 14973          NaN         NaN                NaN           NaN
# 14974          NaN         NaN                NaN           NaN
# 14975          NaN         NaN                NaN           NaN
#
#        gdp_for_year ($)   gdp_per_capita ($)
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# 5                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# 8                    NaN                 NaN
# 9                    NaN                 NaN
# 10                   NaN                 NaN
# 11                   NaN                 NaN
# 12          2.156625e+09               796.0
# 13          2.156625e+09               796.0
# 14          2.156625e+09               796.0
# 15          2.156625e+09               796.0
# 16          2.156625e+09               796.0
# 17          2.156625e+09               796.0
# 18          2.126000e+09               769.0
# 19          2.126000e+09               769.0
# 20          2.126000e+09               769.0
# 21          2.126000e+09               769.0
# 22          2.126000e+09               769.0
# 23          2.126000e+09               769.0
# 24          2.335125e+09               833.0
# 25          2.335125e+09               833.0
# 26          2.335125e+09               833.0
# 27          2.335125e+09               833.0
# 28          2.335125e+09               833.0
# 29          2.335125e+09               833.0
# ...                  ...                 ...
# 14946       2.662085e+12             44585.0
# 14947       2.662085e+12             44585.0
# 14948       2.662085e+12             44585.0
# 14949       2.662085e+12             44585.0
# 14950       2.662085e+12             44585.0
# 14951       2.662085e+12             44585.0
# 14952       2.739819e+12             45594.0
# 14953       2.739819e+12             45594.0
# 14954       2.739819e+12             45594.0
# 14955       2.739819e+12             45594.0
# 14956       2.739819e+12             45594.0
# 14957       2.739819e+12             45594.0
# 14958       3.022828e+12             49906.0
# 14959       3.022828e+12             49906.0
# 14960       3.022828e+12             49906.0
# 14961       3.022828e+12             49906.0
# 14962       3.022828e+12             49906.0
# 14963       3.022828e+12             49906.0
# 14964       2.885570e+12             47240.0
# 14965       2.885570e+12             47240.0
# 14966       2.885570e+12             47240.0
# 14967       2.885570e+12             47240.0
# 14968       2.885570e+12             47240.0
# 14969       2.885570e+12             47240.0
# 14970                NaN                 NaN
# 14971                NaN                 NaN
# 14972                NaN                 NaN
# 14973                NaN                 NaN
# 14974                NaN                 NaN
# 14975                NaN                 NaN
#
# [14976 rows x 11 columns]

# %%
f_cntr = (data['country'] == 'Poland')

# %%
data.loc[f_cntr, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
# Out:
#           sex country  year    generation  suicides_no  population  \
# 4800   female  Poland  1985           NaN          NaN         NaN
# 4801   female  Poland  1985           NaN          NaN         NaN
# 4802   female  Poland  1985           NaN          NaN         NaN
# 4803   female  Poland  1985           NaN          NaN         NaN
# 4804   female  Poland  1985           NaN          NaN         NaN
# 4805   female  Poland  1985           NaN          NaN         NaN
# 4806   female  Poland  1986           NaN          NaN         NaN
# 4807   female  Poland  1986           NaN          NaN         NaN
# 4808   female  Poland  1986           NaN          NaN         NaN
# 4809   female  Poland  1986           NaN          NaN         NaN
# 4810   female  Poland  1986           NaN          NaN         NaN
# 4811   female  Poland  1986           NaN          NaN         NaN
# 4812   female  Poland  1987           NaN          NaN         NaN
# 4813   female  Poland  1987           NaN          NaN         NaN
# 4814   female  Poland  1987           NaN          NaN         NaN
# 4815   female  Poland  1987           NaN          NaN         NaN
# 4816   female  Poland  1987           NaN          NaN         NaN
# 4817   female  Poland  1987           NaN          NaN         NaN
# 4818   female  Poland  1988           NaN          NaN         NaN
# 4819   female  Poland  1988           NaN          NaN         NaN
# 4820   female  Poland  1988           NaN          NaN         NaN
# 4821   female  Poland  1988           NaN          NaN         NaN
# 4822   female  Poland  1988           NaN          NaN         NaN
# 4823   female  Poland  1988           NaN          NaN         NaN
# 4824   female  Poland  1989           NaN          NaN         NaN
# 4825   female  Poland  1989           NaN          NaN         NaN
# 4826   female  Poland  1989           NaN          NaN         NaN
# 4827   female  Poland  1989           NaN          NaN         NaN
# 4828   female  Poland  1989           NaN          NaN         NaN
# 4829   female  Poland  1989           NaN          NaN         NaN
# ...       ...     ...   ...           ...          ...         ...
# 12450    male  Poland  2012    Millenials        509.0   2533873.0
# 12451    male  Poland  2012    Millenials        857.0   3139373.0
# 12452    male  Poland  2012  Generation X       2182.0   5186397.0
# 12453    male  Poland  2012  Generation Z         12.0   1898168.0
# 12454    male  Poland  2012       Boomers       1708.0   3762189.0
# 12455    male  Poland  2012        Silent        290.0    854366.0
# 12456    male  Poland  2013    Millenials        497.0   2443545.0
# 12457    male  Poland  2013    Millenials        810.0   3124764.0
# 12458    male  Poland  2013  Generation X       2013.0   5168551.0
# 12459    male  Poland  2013  Generation Z         16.0   1906361.0
# 12460    male  Poland  2013       Boomers       1755.0   3866967.0
# 12461    male  Poland  2013        Silent        287.0    869774.0
# 12462    male  Poland  2014    Millenials        527.0   2357793.0
# 12463    male  Poland  2014    Millenials        764.0   3087300.0
# 12464    male  Poland  2014  Generation X       1949.0   5170670.0
# 12465    male  Poland  2014  Generation Z          9.0   1929147.0
# 12466    male  Poland  2014       Boomers       1606.0   3963821.0
# 12467    male  Poland  2014        Silent        268.0    888229.0
# 12468    male  Poland  2015    Millenials        440.0   2274111.0
# 12469    male  Poland  2015    Millenials        768.0   3043082.0
# 12470    male  Poland  2015  Generation X       1665.0   5194280.0
# 12471    male  Poland  2015  Generation Z         12.0   1953588.0
# 12472    male  Poland  2015       Boomers       1524.0   4043381.0
# 12473    male  Poland  2015        Silent        288.0    902310.0
# 12474    male  Poland  2016           NaN          NaN         NaN
# 12475    male  Poland  2016           NaN          NaN         NaN
# 12476    male  Poland  2016           NaN          NaN         NaN
# 12477    male  Poland  2016           NaN          NaN         NaN
# 12478    male  Poland  2016           NaN          NaN         NaN
# 12479    male  Poland  2016           NaN          NaN         NaN
#
#        suicides/100k pop
# 4800                 NaN
# 4801                 NaN
# 4802                 NaN
# 4803                 NaN
# 4804                 NaN
# 4805                 NaN
# 4806                 NaN
# 4807                 NaN
# 4808                 NaN
# 4809                 NaN
# 4810                 NaN
# 4811                 NaN
# 4812                 NaN
# 4813                 NaN
# 4814                 NaN
# 4815                 NaN
# 4816                 NaN
# 4817                 NaN
# 4818                 NaN
# 4819                 NaN
# 4820                 NaN
# 4821                 NaN
# 4822                 NaN
# 4823                 NaN
# 4824                 NaN
# 4825                 NaN
# 4826                 NaN
# 4827                 NaN
# 4828                 NaN
# 4829                 NaN
# ...                  ...
# 12450              20.09
# 12451              27.30
# 12452              42.07
# 12453               0.63
# 12454              45.40
# 12455              33.94
# 12456              20.34
# 12457              25.92
# 12458              38.95
# 12459               0.84
# 12460              45.38
# 12461              33.00
# 12462              22.35
# 12463              24.75
# 12464              37.69
# 12465               0.47
# 12466              40.52
# 12467              30.17
# 12468              19.35
# 12469              25.24
# 12470              32.05
# 12471               0.61
# 12472              37.69
# 12473              31.92
# 12474                NaN
# 12475                NaN
# 12476                NaN
# 12477                NaN
# 12478                NaN
# 12479                NaN
#
# [384 rows x 7 columns]

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1985)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1986)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1987)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1988)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1989)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1990)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 172.64

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1991)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 180.27

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1992)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 194.43

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1993)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 187.85000000000002

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1994)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 185.95999999999998

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1995)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 181.7

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1996)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 178.21

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1997)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1998)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 1999)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 184.14999999999998

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2000)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 191.01000000000002

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2001)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 180.65

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2002)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 183.26999999999998

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2003)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 180.15

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2004)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 187.74

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2005)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 186.04

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2006)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 182.85000000000002

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2007)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 166.47

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2008)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 177.38

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2009)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 197.1

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2010)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 190.64

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2011)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 183.85999999999999

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2012)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 192.37

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2013)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 187.59

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2014)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 178.3

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2015)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 166.99

# %%
f_yvsn = (data['country'] == 'Poland') & (data['year'] == 2016)
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides/100k pop'].sum()
# Out:
# 0.0
