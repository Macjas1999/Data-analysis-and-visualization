# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('masterCSVfmfull.csv')

# %%
#data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data.columns
# Out:
# Index(['sex', 'country', 'year', 'age', 'generation', 'suicides_no',
#        'population', 'suicides/100k pop', 'HDI for year', 'gdp_for_year ($) ',
#        'gdp_per_capita ($)'],
#       dtype='object')

# %%
data
# Out:
#           sex     country  year          age       generation  suicides_no  \
# 0      female     Albania  1985  15-24 years              NaN          NaN
# 1      female     Albania  1985  25-34 years              NaN          NaN
# 2      female     Albania  1985  35-54 years              NaN          NaN
# 3      female     Albania  1985   5-14 years              NaN          NaN
# 4      female     Albania  1985  55-74 years              NaN          NaN
# 5      female     Albania  1985    75+ years              NaN          NaN
# 6      female     Albania  1986  15-24 years              NaN          NaN
# 7      female     Albania  1986  25-34 years              NaN          NaN
# 8      female     Albania  1986  35-54 years              NaN          NaN
# 9      female     Albania  1986   5-14 years              NaN          NaN
# 10     female     Albania  1986  55-74 years              NaN          NaN
# ...

# %%
f_cntr = (data['generation'] == 'Boomers')

# %%
data.loc[f_cntr, ['age','sex','country', 'suicides_no']]
# Out:
#                age     sex              country  suicides_no
# 13     25-34 years  female              Albania          4.0
# 19     25-34 years  female              Albania          5.0
# 25     25-34 years  female              Albania          2.0
# 43     25-34 years  female              Albania          4.0
# 44     35-54 years  female              Albania          2.0
# 49     25-34 years  female              Albania          7.0
# 50     35-54 years  female              Albania          7.0
# 55     25-34 years  female              Albania          4.0
# 56     35-54 years  female              Albania          2.0
# 62     35-54 years  female              Albania          8.0
# 68     35-54 years  female              Albania          9.0
# 74     35-54 years  female              Albania          7.0
# 80     35-54 years  female              Albania          9.0
# 86     35-54 years  female              Albania          5.0
# ...

# %%
f_yvsn = (data['age'] == '5-14 years') & (data['sex'] == 'female')
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides_no'].sum()
# Out:
# 16997.0

# %%
f_yvsn = (data['age'] == '5-14 years') & (data['sex'] == 'male')
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides_no'].sum()
# Out:
# 35267.0

# %%
f_yvsn = (data['age'] == '5-14 years')
a_s =data.loc[f_yvsn, ['sex', 'country', 'year', 'generation', 'suicides_no',
       'population', 'suicides/100k pop']]
a_s['suicides_no'].sum()
# Out:
# 52264.0
