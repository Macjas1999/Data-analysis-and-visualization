# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('GermanyssS.csv')

# %%
drop0 = data['sum'] > 0

# %%
gnum = data.loc[drop0 ,['sum', 'year']]

# %%
gnum
# Out:
#         sum  year
# 5   13924.0  1990
# 6   14010.0  1991
# 7   13458.0  1992
# 8   12690.0  1993
# 9   12718.0  1994
# 10  12888.0  1995
# 11  12225.0  1996
# 12  12256.0  1997
# 13  11654.0  1998
# 14  11160.0  1999
# 15  11073.0  2000
# 16  11167.0  2001
# 17  11176.0  2002
# 18  11155.0  2003
# 19  10741.0  2004
# 20  10270.0  2005
# 21   9775.0  2006
# 22   9409.0  2007
# 23   9459.0  2008
# 24   9579.0  2009
# 25  10030.0  2010
# 26  10153.0  2011
# 27   9896.0  2012
# 28  10091.0  2013
# 29  10217.0  2014
# 30  10088.0  2015

# %%
plt.style.use('ggplot')
plt.figure(figsize=(6 ,8))
x = gnum['year']

y = gnum['sum']

x_ind = np.arange(len(x))

plt.barh(x_ind, y,0.75,100, color='#4b4e4e', linestyle='--')


plt.yticks(x_ind, x)


plt.xlabel('Liczba samobójstw')
plt.ylabel('Lata (z pominięciem lat bez danych)')
plt.title('Samobójstwa w Niemczech')

#plt.legend()  label='All Devs'

plt.tight_layout()
plt.savefig('jp.png')

plt.show()

# %%
plt.show()
