# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataM = pd.read_csv('Genersuno.csv')

# %%
#dataF = pd.read_csv('Female_total_world.csv')

# %%
#ftl = (data['sum'] > 0)

# %%
#dm = dataM.loc[ftl]

# %%
#fivethirtyeight

# %%
plt.style.use('ggplot')


x = dataM['generation']

yM = dataM['male']

plt.bar(x,yM, label='gr')

yF = dataM['female']

plt.bar(x,yF, label='gr')



plt.xlabel('Rok')
plt.ylabel('Liczba samobójstw')
plt.title('Liczba samobójstw na przestrzeni lat')

plt.legend()

plt.tight_layout()

#plt.savefig('Albgraph')

plt.show()
